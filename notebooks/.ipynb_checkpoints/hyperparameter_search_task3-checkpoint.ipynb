# %%
from helpers import init, preprocess_data

# %%
SEED = 42
X_train_raw, y_train_cm, X_val_raw, y_val_cm = init(SEED, task=3)
X_train, y_train, X_val, y_val, target_min_cm, target_range_cm = preprocess_data(X_train_raw, y_train_cm, X_val_raw, y_val_cm)
# Out:
# PyTorch: 2.11.0+cu130
# Training rows: 703
# Validation rows: 78
# Input shape: (703, 36)
# Target x range (cm): 0.0 to 280.0
# Target y range (cm): 0.0 to 272.0
# Using split files:
#   train: train_clean_6x6_8cm.csv 703 rows
#   validation: validation_clean_6x6_8cm.csv 78 rows
# RSS scale: 0.8427589535713196
# Target min cm: [0. 0.]
# Target range cm: [280. 272.]

# %% [markdown]
# # Get the model

# %%
from vlp_hackathon.baseline_model import BaselineMLP
from vlp_hackathon.improved_model import ImprovedMLP
model_cls = ImprovedMLP

# %% [markdown]
# # Run a trail

# %%
from torch import nn
import torch
import numpy as np
from matplotlib import pyplot as plt
import copy

def train_model(model, optimizer, loss_fn, epochs, batch_size, plot: bool = False, ret_model: bool = False, lr_scheduler = None):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    X_train_t = torch.from_numpy(X_train).to(device)
    y_train_t = torch.from_numpy(y_train).to(device)
    X_val_t = torch.from_numpy(X_val).to(device)
    y_val_t = torch.from_numpy(y_val).to(device)
    model = model.to(device)

    history = []
    best_model = copy.deepcopy(model)
    lowest_loss = float("inf")
    train_rng = np.random.default_rng(SEED)
    for epoch in range(epochs):
        model.train()
        permutation = train_rng.permutation(len(X_train))
        running = 0.0
        for start in range(0, len(permutation), batch_size):
            idx = permutation[start:start + batch_size]
            xb = X_train_t[idx]
            yb = y_train_t[idx]
            optimizer.zero_grad()
            loss = loss_fn(model(xb), yb)
            loss.backward()
            if loss < lowest_loss:
                best_model = copy.deepcopy(model)
            optimizer.step()
            running += float(loss.item()) * len(idx)

        model.eval()
        with torch.no_grad():
            val_loss = float(loss_fn(model(X_val_t), y_val_t).item())
        history.append((running / len(X_train), val_loss))
        lr = None
        if lr_scheduler is not None:
            lr = lr_scheduler.get_lr()
            lr_scheduler.step()
        print(f"epoch={epoch + 1:02d} train_mse={history[-1][0]:.6f} val_mse={val_loss:.6f} lr={lr}")

    history = np.asarray(history, dtype=np.float32)
    if plot:
        plt.figure(figsize=(6, 4))
        plt.plot(history[:, 0], label="train")
        plt.plot(history[:, 1], label="validation")
        plt.xlabel("Epoch")
        plt.ylabel("MSE on normalized coordinates")
        plt.legend()
        plt.title("Baseline training curve")
        plt.show()

    if ret_model:
        return best_model
    return np.min(history[:, 1])

def run_trial(trial):
    epochs = trial.suggest_int("epochs", 50, 150, log=True)

    print(trial)
    lr = trial.suggest_float("lr", 1e-5, 1e-1, log=True)
    batch_size = trial.suggest_int("batch_size", 16, 4096, log=True)

    depth = trial.suggest_int("depth", 1, 6)
    layers = []
    for layer in range(depth):
        width = trial.suggest_int(f"layer_{layer}", 2, 128, log=True)
        layers.append(width)

    # Start and end are fixed
    layers = [36] + layers + [2]

    act = trial.suggest_categorical("act", ["relu", "tanh", "sigmoid", ""])
    last_act = trial.suggest_categorical("last_act", ["relu", "tanh", "sigmoid", ""])
    layer_norm = trial.suggest_categorical("layer_norm", [True, False])


    model = model_cls(layers=layers, activation=act, last_act=last_act, layer_norm=layer_norm)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()

    lr_scheduler = None
    if trial.suggest_categorical("lr_scheduler", [True, False]):
        lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    return train_model(model, optimizer, loss_fn, epochs, batch_size, lr_scheduler=lr_scheduler)

# %%
import optuna
from optuna.trial import TrialState

study = optuna.create_study(direction='minimize', study_name="task_3", load_if_exists=True, storage="sqlite:///trail_3.db")
study.optimize(run_trial, n_trials=5, show_progress_bar=True)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

print("Study statistics: ")
print("  Number of finished trials: ", len(study.trials))
print("  Number of pruned trials: ", len(pruned_trials))
print("  Number of complete trials: ", len(complete_trials))

print("Best trial:")
trial = study.best_trial

print("  Value: ", trial.value)

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2026-07-09 08:57:50,969] Using an existing study with name 'task_1' instead of creating a new one.
#   0%|          | 0/5 [00:00<?, ?it/s]
# <optuna.trial._trial.Trial object at 0x715bf461eff0>
# Sequential(
#   (0): Linear(in_features=36, out_features=14, bias=True)
#   (1): LayerNorm((14,), eps=1e-05, elementwise_affine=True)
#   (2): Tanh()
#   (3): Linear(in_features=14, out_features=2, bias=True)
#   (4): Sigmoid()
# )
# epoch=01 train_mse=0.087124 val_mse=0.060510 lr=None
# epoch=02 train_mse=0.058348 val_mse=0.039374 lr=None
# epoch=03 train_mse=0.038455 val_mse=0.026188 lr=None
# epoch=04 train_mse=0.026130 val_mse=0.018853 lr=None
# epoch=05 train_mse=0.019174 val_mse=0.014589 lr=None
# epoch=06 train_mse=0.015003 val_mse=0.011833 lr=None
# epoch=07 train_mse=0.012192 val_mse=0.009912 lr=None
# epoch=08 train_mse=0.010154 val_mse=0.008546 lr=None
# epoch=09 train_mse=0.008658 val_mse=0.007608 lr=None
# epoch=10 train_mse=0.007609 val_mse=0.007016 lr=None
# epoch=11 train_mse=0.006937 val_mse=0.006674 lr=None
# epoch=12 train_mse=0.006548 val_mse=0.006466 lr=None
# epoch=13 train_mse=0.006318 val_mse=0.006274 lr=None
# epoch=14 train_mse=0.006124 val_mse=0.006021 lr=None
# epoch=15 train_mse=0.005879 val_mse=0.005681 lr=None
# epoch=16 train_mse=0.005551 val_mse=0.005270 lr=None
# epoch=17 train_mse=0.005153 val_mse=0.004827 lr=None
# epoch=18 train_mse=0.004722 val_mse=0.004391 lr=None
# epoch=19 train_mse=0.004297 val_mse=0.003988 lr=None
# epoch=20 train_mse=0.003907 val_mse=0.003630 lr=None
# epoch=21 train_mse=0.003564 val_mse=0.003318 lr=None
# epoch=22 train_mse=0.003270 val_mse=0.003048 lr=None
# epoch=23 train_mse=0.003020 val_mse=0.002813 lr=None
# epoch=24 train_mse=0.002809 val_mse=0.002608 lr=None
# epoch=25 train_mse=0.002630 val_mse=0.002428 lr=None
# epoch=26 train_mse=0.002476 val_mse=0.002268 lr=None
# epoch=27 train_mse=0.002340 val_mse=0.002124 lr=None
# epoch=28 train_mse=0.002212 val_mse=0.001989 lr=None
# epoch=29 train_mse=0.002088 val_mse=0.001862 lr=None
# epoch=30 train_mse=0.001964 val_mse=0.001739 lr=None
# epoch=31 train_mse=0.001838 val_mse=0.001621 lr=None
# epoch=32 train_mse=0.001712 val_mse=0.001509 lr=None
# epoch=33 train_mse=0.001590 val_mse=0.001405 lr=None
# epoch=34 train_mse=0.001474 val_mse=0.001313 lr=None
# epoch=35 train_mse=0.001370 val_mse=0.001234 lr=None
# epoch=36 train_mse=0.001281 val_mse=0.001169 lr=None
# epoch=37 train_mse=0.001208 val_mse=0.001117 lr=None
# epoch=38 train_mse=0.001150 val_mse=0.001075 lr=None
# epoch=39 train_mse=0.001104 val_mse=0.001040 lr=None
# epoch=40 train_mse=0.001066 val_mse=0.001012 lr=None
# epoch=41 train_mse=0.001035 val_mse=0.000988 lr=None
# epoch=42 train_mse=0.001008 val_mse=0.000968 lr=None
# epoch=43 train_mse=0.000983 val_mse=0.000948 lr=None
# epoch=44 train_mse=0.000960 val_mse=0.000927 lr=None
# epoch=45 train_mse=0.000938 val_mse=0.000903 lr=None
# epoch=46 train_mse=0.000917 val_mse=0.000876 lr=None
# epoch=47 train_mse=0.000896 val_mse=0.000846 lr=None
# epoch=48 train_mse=0.000876 val_mse=0.000817 lr=None
# epoch=49 train_mse=0.000858 val_mse=0.000788 lr=None
# epoch=50 train_mse=0.000840 val_mse=0.000762 lr=None
# epoch=51 train_mse=0.000824 val_mse=0.000739 lr=None
# epoch=52 train_mse=0.000808 val_mse=0.000719 lr=None
# epoch=53 train_mse=0.000793 val_mse=0.000704 lr=None
# epoch=54 train_mse=0.000781 val_mse=0.000691 lr=None
# epoch=55 train_mse=0.000770 val_mse=0.000680 lr=None
# epoch=56 train_mse=0.000760 val_mse=0.000668 lr=None
# epoch=57 train_mse=0.000749 val_mse=0.000655 lr=None
# epoch=58 train_mse=0.000737 val_mse=0.000641 lr=None
# epoch=59 train_mse=0.000723 val_mse=0.000628 lr=None
# epoch=60 train_mse=0.000708 val_mse=0.000616 lr=None
# epoch=61 train_mse=0.000694 val_mse=0.000605 lr=None
# epoch=62 train_mse=0.000680 val_mse=0.000596 lr=None
# epoch=63 train_mse=0.000667 val_mse=0.000588 lr=None
# epoch=64 train_mse=0.000655 val_mse=0.000581 lr=None
# epoch=65 train_mse=0.000643 val_mse=0.000575 lr=None
# epoch=66 train_mse=0.000631 val_mse=0.000568 lr=None
# epoch=67 train_mse=0.000620 val_mse=0.000561 lr=None
# epoch=68 train_mse=0.000609 val_mse=0.000554 lr=None
# epoch=69 train_mse=0.000599 val_mse=0.000546 lr=None
# epoch=70 train_mse=0.000588 val_mse=0.000538 lr=None
# epoch=71 train_mse=0.000578 val_mse=0.000529 lr=None
# epoch=72 train_mse=0.000569 val_mse=0.000521 lr=None
# epoch=73 train_mse=0.000560 val_mse=0.000512 lr=None
# epoch=74 train_mse=0.000551 val_mse=0.000503 lr=None
# epoch=75 train_mse=0.000542 val_mse=0.000494 lr=None
# epoch=76 train_mse=0.000534 val_mse=0.000486 lr=None
# epoch=77 train_mse=0.000526 val_mse=0.000478 lr=None
# epoch=78 train_mse=0.000518 val_mse=0.000470 lr=None
# epoch=79 train_mse=0.000511 val_mse=0.000462 lr=None
# epoch=80 train_mse=0.000504 val_mse=0.000454 lr=None
# epoch=81 train_mse=0.000496 val_mse=0.000446 lr=None
# epoch=82 train_mse=0.000489 val_mse=0.000439 lr=None
# [I 2026-07-09 08:57:51,141] Trial 5 finished with value: 0.0004393027920741588 and parameters: {'epochs': 82, 'lr': 0.014564979848855164, 'batch_size': 1854, 'depth': 1, 'layer_0': 14, 'act': 'tanh', 'last_act': 'sigmoid', 'layer_norm': True, 'lr_scheduler': False}. Best is trial 2 with value: 0.00017523954738862813.
# <optuna.trial._trial.Trial object at 0x715bfe88f170>
# Sequential(
#   (0): Linear(in_features=36, out_features=77, bias=True)
#   (1): LayerNorm((77,), eps=1e-05, elementwise_affine=True)
#   (2): ReLU()
#   (3): Linear(in_features=77, out_features=10, bias=True)
#   (4): LayerNorm((10,), eps=1e-05, elementwise_affine=True)
#   (5): ReLU()
#   (6): Linear(in_features=10, out_features=2, bias=True)
#   (7): Tanh()
# )
# epoch=01 train_mse=0.178944 val_mse=0.047562 lr=[0.015226660685042501]
# /home/lucan/projects/vlc_hackaton/.venv/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:1427: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   _warn_get_lr_called_within_step(self)
# epoch=02 train_mse=0.036782 val_mse=0.020217 lr=[0.01520431644608344]
# epoch=03 train_mse=0.015220 val_mse=0.007426 lr=[0.015167134343894599]
# epoch=04 train_mse=0.007051 val_mse=0.006083 lr=[0.015115187121372147]
# epoch=05 train_mse=0.004556 val_mse=0.003132 lr=[0.015048576424765736]
# epoch=06 train_mse=0.002965 val_mse=0.002054 lr=[0.01496743260461682]
# epoch=07 train_mse=0.001888 val_mse=0.001438 lr=[0.014871914460505991]
# epoch=08 train_mse=0.001298 val_mse=0.001038 lr=[0.014762208930108356]
# epoch=09 train_mse=0.000955 val_mse=0.000857 lr=[0.01463853072316506]
# epoch=10 train_mse=0.000766 val_mse=0.000684 lr=[0.014501121901086777]
# epoch=11 train_mse=0.000631 val_mse=0.000573 lr=[0.014350251403011511]
# epoch=12 train_mse=0.000551 val_mse=0.000492 lr=[0.014186214519243644]
# epoch=13 train_mse=0.000478 val_mse=0.000442 lr=[0.014009332313104295]
# epoch=14 train_mse=0.000421 val_mse=0.000392 lr=[0.013819950992323764]
# epoch=15 train_mse=0.000373 val_mse=0.000351 lr=[0.013618441231205782]
# epoch=16 train_mse=0.000331 val_mse=0.000327 lr=[0.013405197444889265]
# epoch=17 train_mse=0.000307 val_mse=0.000274 lr=[0.01318063701712714]
# epoch=18 train_mse=0.000269 val_mse=0.000243 lr=[0.012945199483092586]
# epoch=19 train_mse=0.000251 val_mse=0.000220 lr=[0.01269934566881083]
# epoch=57 train_mse=0.000093 val_mse=0.000077 lr=[0.001427093205047243]
# epoch=58 train_mse=0.000092 val_mse=0.000079 lr=[0.0012376023379245594]
# epoch=59 train_mse=0.000092 val_mse=0.000076 lr=[0.0010605935963317195]
# epoch=60 train_mse=0.000091 val_mse=0.000077 lr=[0.0008964093972494657]
# epoch=61 train_mse=0.000091 val_mse=0.000076 lr=[0.0007453657720092792]
# epoch=62 train_mse=0.000090 val_mse=0.000078 lr=[0.0006077511879294713]
# epoch=63 train_mse=0.000090 val_mse=0.000076 lr=[0.0004838250998035284]
# epoch=64 train_mse=0.000090 val_mse=0.000076 lr=[0.00037381599105250633]
# epoch=65 train_mse=0.000090 val_mse=0.000075 lr=[0.00027791843197373764]
# epoch=66 train_mse=0.000090 val_mse=0.000075 lr=[0.00019628816477670088]
# epoch=67 train_mse=0.000090 val_mse=0.000075 lr=[0.00012903297222691422]
# epoch=68 train_mse=0.000090 val_mse=0.000076 lr=[7.619372765769833e-05]
# epoch=69 train_mse=0.000090 val_mse=0.000076 lr=[3.7699758349441924e-05]
# epoch=70 train_mse=0.000090 val_mse=0.000076 lr=[1.3245352599676117e-05]
# epoch=71 train_mse=0.000090 val_mse=0.000076 lr=[1.8629314584850136e-06]
# [I 2026-07-09 08:57:52,196] Trial 6 finished with value: 7.527945126639679e-05 and parameters: {'epochs': 71, 'lr': 0.015219208959208563, 'batch_size': 74, 'depth': 2, 'layer_0': 77, 'layer_1': 10, 'act': 'relu', 'last_act': 'tanh', 'layer_norm': True, 'lr_scheduler': True}. Best is trial 6 with value: 7.527945126639679e-05.
# <optuna.trial._trial.Trial object at 0x715bf4a4f8c0>
# Sequential(
#   (0): Linear(in_features=36, out_features=4, bias=True)
#   (1): LayerNorm((4,), eps=1e-05, elementwise_affine=True)
#   (2): Identity()
#   (3): Linear(in_features=4, out_features=2, bias=True)
#   (4): Sigmoid()
# )
# epoch=01 train_mse=0.109968 val_mse=0.097170 lr=None
# epoch=02 train_mse=0.109068 val_mse=0.096239 lr=None
# epoch=03 train_mse=0.108201 val_mse=0.095351 lr=None
# epoch=04 train_mse=0.107374 val_mse=0.094496 lr=None
# epoch=05 train_mse=0.106564 val_mse=0.093688 lr=None
# epoch=06 train_mse=0.105782 val_mse=0.092896 lr=None
# epoch=07 train_mse=0.105025 val_mse=0.092120 lr=None
# epoch=08 train_mse=0.104269 val_mse=0.091386 lr=None
# epoch=09 train_mse=0.103536 val_mse=0.090674 lr=None
# epoch=10 train_mse=0.102812 val_mse=0.089979 lr=None
# epoch=11 train_mse=0.102108 val_mse=0.089295 lr=None
# epoch=12 train_mse=0.101409 val_mse=0.088620 lr=None
# epoch=13 train_mse=0.100721 val_mse=0.087961 lr=None
# epoch=14 train_mse=0.100033 val_mse=0.087316 lr=None
# epoch=15 train_mse=0.099359 val_mse=0.086676 lr=None
# epoch=16 train_mse=0.098688 val_mse=0.086054 lr=None
# epoch=17 train_mse=0.098027 val_mse=0.085437 lr=None
# epoch=114 train_mse=0.050796 val_mse=0.046552 lr=None
# epoch=115 train_mse=0.050495 val_mse=0.046296 lr=None
# epoch=116 train_mse=0.050200 val_mse=0.046037 lr=None
# epoch=117 train_mse=0.049905 val_mse=0.045783 lr=None
# epoch=118 train_mse=0.049617 val_mse=0.045531 lr=None
# epoch=119 train_mse=0.049328 val_mse=0.045284 lr=None
# [I 2026-07-09 08:57:53,993] Trial 7 finished with value: 0.04528391733765602 and parameters: {'epochs': 119, 'lr': 3.115021828763918e-05, 'batch_size': 45, 'depth': 1, 'layer_0': 4, 'act': '', 'last_act': 'sigmoid', 'layer_norm': True, 'lr_scheduler': False}. Best is trial 6 with value: 7.527945126639679e-05.
# <optuna.trial._trial.Trial object at 0x715bfe837c80>
# Sequential(
#   (0): Linear(in_features=36, out_features=2, bias=True)
#   (1): Sigmoid()
#   (2): Linear(in_features=2, out_features=7, bias=True)
#   (3): Sigmoid()
#   (4): Linear(in_features=7, out_features=83, bias=True)
#   (5): Sigmoid()
#   (6): Linear(in_features=83, out_features=2, bias=True)
#   (7): Tanh()
# )
# epoch=01 train_mse=0.447757 val_mse=0.405342 lr=None
# epoch=02 train_mse=0.382957 val_mse=0.346077 lr=None
# epoch=03 train_mse=0.325684 val_mse=0.295193 lr=None
# epoch=04 train_mse=0.276806 val_mse=0.252577 lr=None
# epoch=05 train_mse=0.236337 val_mse=0.217740 lr=None
# epoch=06 train_mse=0.204266 val_mse=0.189530 lr=None
# epoch=07 train_mse=0.178173 val_mse=0.167793 lr=None
# epoch=08 train_mse=0.158858 val_mse=0.150851 lr=None
# epoch=09 train_mse=0.143646 val_mse=0.138155 lr=None
# epoch=10 train_mse=0.132480 val_mse=0.128721 lr=None
# epoch=11 train_mse=0.124125 val_mse=0.121776 lr=None
# epoch=12 train_mse=0.118031 val_mse=0.116690 lr=None
# epoch=13 train_mse=0.113717 val_mse=0.112748 lr=None
# epoch=14 train_mse=0.110420 val_mse=0.109973 lr=None
# epoch=15 train_mse=0.107980 val_mse=0.107963 lr=None
# epoch=16 train_mse=0.106331 val_mse=0.106503 lr=None
# epoch=17 train_mse=0.105027 val_mse=0.105376 lr=None
# epoch=18 train_mse=0.104114 val_mse=0.104590 lr=None
# epoch=19 train_mse=0.103433 val_mse=0.104032 lr=None
# epoch=20 train_mse=0.102854 val_mse=0.103528 lr=None
# epoch=21 train_mse=0.102528 val_mse=0.103150 lr=None
# epoch=22 train_mse=0.102269 val_mse=0.102778 lr=None
# epoch=23 train_mse=0.102017 val_mse=0.102653 lr=None
# epoch=24 train_mse=0.101891 val_mse=0.102568 lr=None
# epoch=25 train_mse=0.101778 val_mse=0.102428 lr=None
# epoch=26 train_mse=0.101714 val_mse=0.102389 lr=None
# epoch=27 train_mse=0.101639 val_mse=0.102285 lr=None
# epoch=28 train_mse=0.101602 val_mse=0.102284 lr=None
# epoch=29 train_mse=0.101573 val_mse=0.102257 lr=None
# epoch=30 train_mse=0.101547 val_mse=0.102164 lr=None
# epoch=31 train_mse=0.101542 val_mse=0.102104 lr=None
# epoch=79 train_mse=0.101204 val_mse=0.101556 lr=None
# epoch=80 train_mse=0.101192 val_mse=0.101784 lr=None
# epoch=81 train_mse=0.101148 val_mse=0.101822 lr=None
# epoch=82 train_mse=0.101166 val_mse=0.101683 lr=None
# epoch=83 train_mse=0.101119 val_mse=0.101643 lr=None
# epoch=84 train_mse=0.101107 val_mse=0.101699 lr=None
# epoch=85 train_mse=0.101100 val_mse=0.101695 lr=None
# epoch=86 train_mse=0.101106 val_mse=0.101766 lr=None
# epoch=87 train_mse=0.101075 val_mse=0.101665 lr=None
# epoch=88 train_mse=0.101049 val_mse=0.101533 lr=None
# epoch=89 train_mse=0.101057 val_mse=0.101428 lr=None
# epoch=90 train_mse=0.101023 val_mse=0.101514 lr=None
# epoch=91 train_mse=0.101037 val_mse=0.101648 lr=None
# epoch=92 train_mse=0.101009 val_mse=0.101493 lr=None
# epoch=93 train_mse=0.100977 val_mse=0.101568 lr=None
# epoch=94 train_mse=0.100981 val_mse=0.101423 lr=None
# epoch=95 train_mse=0.100947 val_mse=0.101519 lr=None
# epoch=96 train_mse=0.100934 val_mse=0.101572 lr=None
# epoch=97 train_mse=0.100928 val_mse=0.101486 lr=None
# epoch=98 train_mse=0.100914 val_mse=0.101281 lr=None
# epoch=99 train_mse=0.100906 val_mse=0.101355 lr=None
# epoch=100 train_mse=0.100863 val_mse=0.101355 lr=None
# epoch=101 train_mse=0.100858 val_mse=0.101405 lr=None
# epoch=102 train_mse=0.100825 val_mse=0.101291 lr=None
# epoch=103 train_mse=0.100869 val_mse=0.101125 lr=None
# epoch=104 train_mse=0.100790 val_mse=0.101206 lr=None
# epoch=105 train_mse=0.100748 val_mse=0.101396 lr=None
# epoch=106 train_mse=0.100745 val_mse=0.101463 lr=None
# epoch=107 train_mse=0.100755 val_mse=0.101460 lr=None
# epoch=108 train_mse=0.100785 val_mse=0.101002 lr=None
# epoch=109 train_mse=0.100698 val_mse=0.101062 lr=None
# epoch=110 train_mse=0.100664 val_mse=0.101102 lr=None
# epoch=111 train_mse=0.100667 val_mse=0.101159 lr=None
# [I 2026-07-09 08:57:54,992] Trial 8 finished with value: 0.10100194811820984 and parameters: {'epochs': 111, 'lr': 0.00017198673898921127, 'batch_size': 82, 'depth': 3, 'layer_0': 2, 'layer_1': 7, 'layer_2': 83, 'act': 'sigmoid', 'last_act': 'tanh', 'layer_norm': False, 'lr_scheduler': False}. Best is trial 6 with value: 7.527945126639679e-05.
# <optuna.trial._trial.Trial object at 0x715bee3fc8c0>
# Sequential(
#   (0): Linear(in_features=36, out_features=2, bias=True)
#   (1): LayerNorm((2,), eps=1e-05, elementwise_affine=True)
#   (2): Sigmoid()
#   (3): Linear(in_features=2, out_features=11, bias=True)
#   (4): LayerNorm((11,), eps=1e-05, elementwise_affine=True)
#   (5): Sigmoid()
#   (6): Linear(in_features=11, out_features=30, bias=True)
#   (7): LayerNorm((30,), eps=1e-05, elementwise_affine=True)
#   (8): Sigmoid()
#   (9): Linear(in_features=30, out_features=87, bias=True)
#   (10): LayerNorm((87,), eps=1e-05, elementwise_affine=True)
#   (11): Sigmoid()
#   (12): Linear(in_features=87, out_features=82, bias=True)
#   (13): LayerNorm((82,), eps=1e-05, elementwise_affine=True)
#   (14): Sigmoid()
#   (15): Linear(in_features=82, out_features=24, bias=True)
#   (16): LayerNorm((24,), eps=1e-05, elementwise_affine=True)
#   (17): Sigmoid()
#   (18): Linear(in_features=24, out_features=2, bias=True)
#   (19): Tanh()
# )
# epoch=01 train_mse=0.214624 val_mse=0.102997 lr=None
# epoch=02 train_mse=0.107271 val_mse=0.103849 lr=None
# epoch=03 train_mse=0.105618 val_mse=0.102436 lr=None
# epoch=04 train_mse=0.104766 val_mse=0.107864 lr=None
# epoch=05 train_mse=0.107877 val_mse=0.104107 lr=None
# epoch=06 train_mse=0.104891 val_mse=0.108975 lr=None
# epoch=07 train_mse=0.107969 val_mse=0.107158 lr=None
# epoch=08 train_mse=0.103538 val_mse=0.103066 lr=None
# epoch=09 train_mse=0.105824 val_mse=0.102103 lr=None
# epoch=10 train_mse=0.103394 val_mse=0.103321 lr=None
# epoch=11 train_mse=0.104335 val_mse=0.102773 lr=None
# epoch=12 train_mse=0.103555 val_mse=0.102011 lr=None
# epoch=13 train_mse=0.104995 val_mse=0.102549 lr=None
# epoch=14 train_mse=0.103402 val_mse=0.103202 lr=None
# epoch=15 train_mse=0.103892 val_mse=0.102945 lr=None
# epoch=16 train_mse=0.103977 val_mse=0.103676 lr=None
# epoch=17 train_mse=0.103750 val_mse=0.104958 lr=None
# epoch=18 train_mse=0.104275 val_mse=0.103555 lr=None
# epoch=19 train_mse=0.103274 val_mse=0.102515 lr=None
# epoch=20 train_mse=0.103363 val_mse=0.101961 lr=None
# epoch=21 train_mse=0.103778 val_mse=0.107520 lr=None
# epoch=22 train_mse=0.105000 val_mse=0.101966 lr=None
# epoch=23 train_mse=0.102912 val_mse=0.104856 lr=None
# epoch=24 train_mse=0.105265 val_mse=0.101828 lr=None
# epoch=25 train_mse=0.103029 val_mse=0.106242 lr=None
# epoch=26 train_mse=0.104196 val_mse=0.105585 lr=None
# epoch=27 train_mse=0.103535 val_mse=0.103318 lr=None
# epoch=28 train_mse=0.102708 val_mse=0.101692 lr=None
# epoch=29 train_mse=0.102453 val_mse=0.102014 lr=None
# epoch=30 train_mse=0.105702 val_mse=0.103187 lr=None
# epoch=31 train_mse=0.103456 val_mse=0.103278 lr=None
# epoch=32 train_mse=0.103919 val_mse=0.102243 lr=None
# epoch=33 train_mse=0.103144 val_mse=0.103160 lr=None
# epoch=34 train_mse=0.104310 val_mse=0.105480 lr=None
# epoch=35 train_mse=0.104440 val_mse=0.102532 lr=None
# epoch=36 train_mse=0.103234 val_mse=0.106142 lr=None
# epoch=37 train_mse=0.103974 val_mse=0.104308 lr=None
# epoch=38 train_mse=0.103829 val_mse=0.107119 lr=None
# epoch=39 train_mse=0.104106 val_mse=0.103779 lr=None
# epoch=40 train_mse=0.104380 val_mse=0.102797 lr=None
# epoch=41 train_mse=0.105546 val_mse=0.106110 lr=None
# epoch=42 train_mse=0.104201 val_mse=0.102028 lr=None
# epoch=43 train_mse=0.103143 val_mse=0.101732 lr=None
# epoch=44 train_mse=0.102263 val_mse=0.102417 lr=None
# epoch=45 train_mse=0.103288 val_mse=0.109202 lr=None
# epoch=46 train_mse=0.104435 val_mse=0.103706 lr=None
# epoch=47 train_mse=0.103801 val_mse=0.102108 lr=None
# epoch=48 train_mse=0.103980 val_mse=0.104620 lr=None
# epoch=49 train_mse=0.103142 val_mse=0.104187 lr=None
# epoch=50 train_mse=0.103210 val_mse=0.105862 lr=None
# epoch=51 train_mse=0.102910 val_mse=0.101682 lr=None
# epoch=52 train_mse=0.102947 val_mse=0.103226 lr=None
# epoch=53 train_mse=0.103306 val_mse=0.102210 lr=None
# epoch=54 train_mse=0.103064 val_mse=0.103622 lr=None
# [I 2026-07-09 08:58:00,821] Trial 9 finished with value: 0.10168237239122391 and parameters: {'epochs': 54, 'lr': 0.07836314463000932, 'batch_size': 21, 'depth': 6, 'layer_0': 2, 'layer_1': 11, 'layer_2': 30, 'layer_3': 87, 'layer_4': 82, 'layer_5': 24, 'act': 'sigmoid', 'last_act': 'tanh', 'layer_norm': True, 'lr_scheduler': False}. Best is trial 6 with value: 7.527945126639679e-05.
# Study statistics:
#   Number of finished trials:  10
#   Number of pruned trials:  0
#   Number of complete trials:  10
# Best trial:
#   Value:  7.527945126639679e-05
#   Params:
#     epochs: 71
#     lr: 0.015219208959208563
#     batch_size: 74
#     depth: 2
#     layer_0: 77
#     layer_1: 10
#     act: relu
#     last_act: tanh
#     layer_norm: True
#     lr_scheduler: True

# %%
from plotly.io import show

fig = optuna.visualization.plot_optimization_history(study)
show(fig)

fig = optuna.visualization.plot_param_importances(study)
show(fig)

fig = optuna.visualization.plot_slice(study)
show(fig)

# %% [markdown]
# # Make the best model

# %%
best_params = study.best_params
print(best_params)

layers = []
for layer_idx in range(best_params["depth"]):
    layer_name = f"layer_{layer_idx}"
    layer_size = best_params[layer_name]
    layers.append(layer_size)
layers = [36] + layers + [2]
best_model = model_cls(layers=layers, activation=best_params["act"], last_act=best_params["last_act"])

epochs = best_params["epochs"]
batch_size = best_params["batch_size"]
optimizer = torch.optim.Adam(best_model.parameters(), lr=best_params["lr"])
if best_params["lr_scheduler"]:
    lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
else:
    lr_scheduler = None
loss_fn = nn.MSELoss()
best_model = train_model(best_model, optimizer, loss_fn, epochs, batch_size, plot=True, ret_model=True, lr_scheduler=lr_scheduler)
# Out:
# {'epochs': 71, 'lr': 0.015219208959208563, 'batch_size': 74, 'depth': 2, 'layer_0': 77, 'layer_1': 10, 'act': 'relu', 'last_act': 'tanh', 'layer_norm': True, 'lr_scheduler': True}
# Sequential(
#   (0): Linear(in_features=36, out_features=77, bias=True)
#   (1): LayerNorm((77,), eps=1e-05, elementwise_affine=True)
#   (2): ReLU()
#   (3): Linear(in_features=77, out_features=10, bias=True)
#   (4): LayerNorm((10,), eps=1e-05, elementwise_affine=True)
#   (5): ReLU()
#   (6): Linear(in_features=10, out_features=2, bias=True)
#   (7): Tanh()
# )
# epoch=01 train_mse=0.107980 val_mse=0.038956 lr=[0.015226660685042501]
# epoch=02 train_mse=0.034349 val_mse=0.015445 lr=[0.01520431644608344]
# epoch=03 train_mse=0.010744 val_mse=0.006816 lr=[0.015167134343894599]
# epoch=04 train_mse=0.005818 val_mse=0.003108 lr=[0.015115187121372147]
# epoch=05 train_mse=0.002984 val_mse=0.001786 lr=[0.015048576424765736]
# epoch=06 train_mse=0.001750 val_mse=0.001072 lr=[0.01496743260461682]
# epoch=07 train_mse=0.001008 val_mse=0.000621 lr=[0.014871914460505991]
# epoch=08 train_mse=0.000747 val_mse=0.000563 lr=[0.014762208930108356]
# epoch=09 train_mse=0.000612 val_mse=0.000413 lr=[0.01463853072316506]
# epoch=10 train_mse=0.000521 val_mse=0.000382 lr=[0.014501121901086777]
# epoch=11 train_mse=0.000432 val_mse=0.000308 lr=[0.014350251403011511]
# epoch=12 train_mse=0.000373 val_mse=0.000282 lr=[0.014186214519243644]
# epoch=13 train_mse=0.000334 val_mse=0.000231 lr=[0.014009332313104295]
# epoch=14 train_mse=0.000306 val_mse=0.000222 lr=[0.013819950992323764]
# epoch=15 train_mse=0.000289 val_mse=0.000245 lr=[0.013618441231205782]
# /home/lucan/projects/vlc_hackaton/.venv/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:1427: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   _warn_get_lr_called_within_step(self)
# epoch=16 train_mse=0.000273 val_mse=0.000180 lr=[0.013405197444889265]
# epoch=17 train_mse=0.000256 val_mse=0.000195 lr=[0.01318063701712714]
# epoch=18 train_mse=0.000228 val_mse=0.000161 lr=[0.012945199483092586]
# epoch=19 train_mse=0.000212 val_mse=0.000155 lr=[0.01269934566881083]
# epoch=20 train_mse=0.000195 val_mse=0.000157 lr=[0.0124435567888995]
# epoch=21 train_mse=0.000197 val_mse=0.000128 lr=[0.012178333504381796]
# epoch=22 train_mse=0.000172 val_mse=0.000126 lr=[0.011904194942414592]
# epoch=23 train_mse=0.000151 val_mse=0.000130 lr=[0.011621677679848043]
# epoch=24 train_mse=0.000154 val_mse=0.000116 lr=[0.01133133469260336]
# epoch=25 train_mse=0.000145 val_mse=0.000142 lr=[0.011033734272922157]
# epoch=26 train_mse=0.000139 val_mse=0.000111 lr=[0.01072945891660294]
# epoch=27 train_mse=0.000136 val_mse=0.000099 lr=[0.010419104182398576]
# epoch=28 train_mse=0.000129 val_mse=0.000110 lr=[0.010103277525802144]
# epoch=29 train_mse=0.000124 val_mse=0.000107 lr=[0.009782597109497864]
# epoch=30 train_mse=0.000118 val_mse=0.000096 lr=[0.00945769059279846]
# epoch=31 train_mse=0.000108 val_mse=0.000090 lr=[0.009129193902429871]
# epoch=32 train_mse=0.000105 val_mse=0.000087 lr=[0.008797749987059286]
# epoch=33 train_mse=0.000103 val_mse=0.000087 lr=[0.008464007557992356]
# epoch=34 train_mse=0.000097 val_mse=0.000083 lr=[0.008128619818489747]
# epoch=35 train_mse=0.000096 val_mse=0.000086 lr=[0.007792243184172863]
# epoch=36 train_mse=0.000101 val_mse=0.000098 lr=[0.007455535997002008]
# epoch=37 train_mse=0.000102 val_mse=0.000084 lr=[0.007119157235318218]
# epoch=38 train_mse=0.000090 val_mse=0.000075 lr=[0.006783765222442066]
# epoch=39 train_mse=0.000087 val_mse=0.000077 lr=[0.006450016336317918]
# epoch=40 train_mse=0.000084 val_mse=0.000074 lr=[0.006118563722681095]
# epoch=41 train_mse=0.000084 val_mse=0.000074 lr=[0.005790056014206453]
# epoch=42 train_mse=0.000082 val_mse=0.000069 lr=[0.0054651360580699904]
# epoch=43 train_mse=0.000080 val_mse=0.000083 lr=[0.005144439654318926]
# epoch=44 train_mse=0.000081 val_mse=0.000068 lr=[0.004828594307398891]
# epoch=45 train_mse=0.000079 val_mse=0.000069 lr=[0.004518217993127028]
# epoch=46 train_mse=0.000077 val_mse=0.000072 lr=[0.0042139179433250415]
# epoch=47 train_mse=0.000075 val_mse=0.000067 lr=[0.003916289450231196]
# epoch=48 train_mse=0.000074 val_mse=0.000070 lr=[0.0036259146926901926]
# epoch=49 train_mse=0.000076 val_mse=0.000067 lr=[0.0033433615859660587]
# epoch=50 train_mse=0.000078 val_mse=0.000068 lr=[0.0030691826568223957]
# epoch=51 train_mse=0.000073 val_mse=0.000064 lr=[0.0028039139452491965]
# epoch=52 train_mse=0.000071 val_mse=0.000064 lr=[0.002548073933856198]
# epoch=53 train_mse=0.000070 val_mse=0.000063 lr=[0.002302162505456099]
# epoch=54 train_mse=0.000069 val_mse=0.000068 lr=[0.002066659928658435]
# epoch=55 train_mse=0.000069 val_mse=0.000071 lr=[0.0018420258702743868]
# epoch=56 train_mse=0.000070 val_mse=0.000066 lr=[0.0016286984318151987]
# epoch=57 train_mse=0.000070 val_mse=0.000063 lr=[0.001427093205047243]
# epoch=58 train_mse=0.000067 val_mse=0.000064 lr=[0.0012376023379245594]
# epoch=59 train_mse=0.000068 val_mse=0.000064 lr=[0.0010605935963317195]
# epoch=60 train_mse=0.000066 val_mse=0.000063 lr=[0.0008964093972494657]
# epoch=61 train_mse=0.000066 val_mse=0.000064 lr=[0.0007453657720092792]
# epoch=62 train_mse=0.000066 val_mse=0.000062 lr=[0.0006077511879294713]
# epoch=63 train_mse=0.000066 val_mse=0.000065 lr=[0.0004838250998035284]
# epoch=64 train_mse=0.000065 val_mse=0.000062 lr=[0.00037381599105250633]
# epoch=65 train_mse=0.000065 val_mse=0.000062 lr=[0.00027791843197373764]
# epoch=66 train_mse=0.000065 val_mse=0.000062 lr=[0.00019628816477670088]
# epoch=67 train_mse=0.000065 val_mse=0.000064 lr=[0.00012903297222691422]
# epoch=68 train_mse=0.000065 val_mse=0.000063 lr=[7.619372765769833e-05]
# epoch=69 train_mse=0.000065 val_mse=0.000063 lr=[3.7699758349441924e-05]
# epoch=70 train_mse=0.000065 val_mse=0.000063 lr=[1.3245352599676117e-05]
# epoch=71 train_mse=0.000065 val_mse=0.000063 lr=[1.8629314584850136e-06]

# %% [markdown]
# # Make the baseline model

# %%
original_model = BaselineMLP(input_features=36)
history = []
epochs = 25
batch_size = 512
optimizer = torch.optim.Adam(original_model.parameters(), lr=1e-3)
loss_fn = nn.MSELoss()
original_model = train_model(original_model, optimizer, loss_fn, epochs, batch_size, plot=True, ret_model=True)
# Out:
# epoch=01 train_mse=0.102053 val_mse=0.101167
# epoch=02 train_mse=0.101494 val_mse=0.100681
# epoch=03 train_mse=0.100951 val_mse=0.100189
# epoch=04 train_mse=0.100392 val_mse=0.099680
# epoch=05 train_mse=0.099829 val_mse=0.099157
# epoch=06 train_mse=0.099232 val_mse=0.098595
# epoch=07 train_mse=0.098597 val_mse=0.097982
# epoch=08 train_mse=0.097927 val_mse=0.097318
# epoch=09 train_mse=0.097187 val_mse=0.096594
# epoch=10 train_mse=0.096380 val_mse=0.095780
# epoch=11 train_mse=0.095506 val_mse=0.094890
# epoch=12 train_mse=0.094558 val_mse=0.093906
# epoch=13 train_mse=0.093513 val_mse=0.092824
# epoch=14 train_mse=0.092374 val_mse=0.091647
# epoch=15 train_mse=0.091119 val_mse=0.090372
# epoch=16 train_mse=0.089752 val_mse=0.088955
# epoch=17 train_mse=0.088253 val_mse=0.087395
# epoch=18 train_mse=0.086648 val_mse=0.085718
# epoch=19 train_mse=0.084917 val_mse=0.083912
# epoch=20 train_mse=0.083046 val_mse=0.081977
# epoch=21 train_mse=0.081050 val_mse=0.079907
# epoch=22 train_mse=0.078941 val_mse=0.077706
# epoch=23 train_mse=0.076694 val_mse=0.075381
# epoch=24 train_mse=0.074341 val_mse=0.072933
# epoch=25 train_mse=0.071847 val_mse=0.070356

# %% [markdown]
# # Compare performance

# %%
from vlp_hackathon.metrics import euclidean_errors_cm

def eval_model(model, name: str):
    model.eval()
    with torch.no_grad():
        float_norm = model(torch.from_numpy(X_val)).numpy()
    float_pred_cm = target_min_cm + float_norm * target_range_cm
    float_errors = euclidean_errors_cm(float_pred_cm, y_val_cm)

    print(f"\n{name}:")
    print(f"Float validation mean error:   {float_errors.mean():.3f} cm")
    print(f"Float validation median error: {np.median(float_errors):.3f} cm")
    print(f"Float validation p95 error:    {np.percentile(float_errors, 95):.3f} cm")
    return float_pred_cm

errors = []
for model, name in [(original_model, "original"), (best_model, "best")]:
    errors.append(eval_model(model, name))

plt.figure(figsize=(5, 5))
n_show = min(1500, len(y_val_cm))
plt.scatter(y_val_cm[:n_show, 0], y_val_cm[:n_show, 1], s=4, alpha=0.25, label="ground truth")
plt.scatter(errors[0][:n_show, 0], errors[0][:n_show, 1], s=4, alpha=0.25, label="pred_original")
plt.scatter(errors[1][:n_show, 0], errors[1][:n_show, 1], s=4, alpha=0.25, label="pred_improved")
plt.xlabel("x (cm)")
plt.ylabel("y (cm)")
plt.legend(markerscale=3)
plt.title("Clean validation positions")
plt.show()
# Out:
# original:
# Float validation mean error:   98.343 cm
# Float validation median error: 95.517 cm
# Float validation p95 error:    152.913 cm
#
# best:
# Float validation mean error:   3.887 cm
# Float validation median error: 3.088 cm
# Float validation p95 error:    11.786 cm
